# %%
import requests

url = "https://api.search.brave.com/res/v1/web/search"
headers = {
    "Accept": "application/json",
    "Accept-Encoding": "gzip",
    "X-Subscription-Token": "BSAExMIBvZpkrdZ4Ld655ZN0gSZGTqY"
}
params = {
    "q": "prime minister of india"
}

response = requests.get(url, headers=headers, params=params)
if response.status_code == 200:
    print(response.json())
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# {'query': {'original': 'prime minister of india', 'show_strict_warning': False, 'is_navigational': False, 'is_news_breaking': False, 'spellcheck_off': True, 'country': 'us', 'bad_results': False, 'should_fallback': False, 'postal_code': '', 'city': '', 'header_country': '', 'more_results_available': True, 'state': ''}, 'mixed': {'type': 'mixed', 'main': [{'type': 'web', 'index': 0, 'all': False}, {'type': 'web', 'index': 1, 'all': False}, {'type': 'news', 'all': True}, {'type': 'web', 'index': 2, 'all': False}, {'type': 'videos', 'all': True}, {'type': 'web', 'index': 3, 'all': False}, {'type': 'web', 'index': 4, 'all': False}, {'type': 'web', 'index': 5, 'all': False}, {'type': 'web', 'index': 6, 'all': False}, {'type': 'web', 'index': 7, 'all': False}, {'type': 'web', 'index': 8, 'all': False}, {'type': 'web', 'index': 9, 'all': False}, {'type': 'web', 'index': 10, 'all': False}, {'type': 'web', 'index': 11, 'all': False}, {'type': 'web', 'index': 12, 'all': False}, {'type': 'web', 'index': 13, 'all': False}, {'type': 'web', 'index': 14, 'all': False}, {'type': 'web', 'index': 15, 'all': False}, {'type': 'web', 'index': 16, 'all': False}, {'type': 'web', 'index': 17, 'all': False}, {'type': 'web', 'index': 18, 'all': False}, {'type': 'web', 'index': 19, 'all': False}], 'top': [], 'side': []}, 'news': {'type': 'news', 'results': [{'title': 'State Visit of President of the Republic of Singapore to ...', 'url': 'https://www.mea.gov.in/press-releases.htm', 'is_source_local': False, 'is_source_both': False, 'description': 'Official portal <strong>of</strong> External Affairs Ministry, Government <strong>of</strong> <strong>India</strong>. Find Statements, Interviews, Press Releases, Media Briefings and latest updates <strong>of</strong> MEA.', 'page_age': '2025-01-18T06:58:50', 'family_friendly': True, 'meta_url': {'scheme': 'https', 'netloc': 'mea.gov.in', 'hostname': 'www.mea.gov.in', 'favicon': 'https://imgs.search.brave.com/ys7qCPcT2zGkyAQNB7S2oSRDHnXbIiRZ8DnUNoAzP38/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYzk3OGJkODU2/MjhkNTczODk3ZWEy/MWZmZTk2NmQ0NGUx/ZjY0OTRiZWM0YzMx/ZTExZDM4NzU4M2Rh/ZTcxNjk5Zi93d3cu/bWVhLmdvdi5pbi8', 'path': '› press-releases.htm'}, 'breaking': False, 'is_live': False, 'age': '1 day ago'}, {'title': 'Union Home Minister and Minister of Cooperation Shri Amit Shah inaugurates the state-of-the-art Archaeological Experiential Museum, Prerna Complex, and Vadnagar Sports Complex in Vadnagar, Gujarat', 'url': 'https://pib.gov.in/PressReleaseIframePage.aspx?PRID=2093525', 'is_source_local': False, 'is_source_both': False, 'description': 'Union Home <strong>Minister</strong> and <strong>Minister</strong> <strong>of</strong> Cooperation, Shri Amit Shah, today inaugurated the Archaeologica', 'page_age': '2025-01-16T21:25:09', 'family_friendly': True, 'meta_url': {'scheme': 'https', 'netloc': 'pib.gov.in', 'hostname': 'pib.gov.in', 'favicon': 'https://imgs.search.brave.com/RnxIwOJ-o5tOv2x7cMB8D0tMsMf0Eu2RPEdH2dj6Iu4/rs:fit:32:32:1:0/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjU5NmM2YTcw/ZDBjZjg1ZDE3MDE0/Mjg0ZTdjMGRlNWY0/ZjhiYjUyZTAwNTRm/ZmU4ZWU1ZTA3MmFh/OGUzZGMyMi9waWIu/Z292LmluLw', 'path': '› PressReleaseIframePage.aspx'}, 'breaking': False, 'is_live': False, 'thumbnail': {'src': 'https://imgs.search.brave.com/ZE2zgyQDfEmCYhFUqfcuoozTbdAdYD8RiA2UQzYQE2M/rs:fit:200:200:1:0/g:ce/aHR0cHM6Ly8xNjQu/MTAwLjE1OC4xNjgv/aW1hZ2VzL2luZGlh/bi1lbWJsZW0ucG5n', 'original': 'https://164.100.158.168/images/indian-emblem.png'}, 'age': '3 days ago'}, {'title': 'Social justice and a lost chance by a Prime Minister - The Hindu', 'url': 'https://www.thehindu.com/opinion/lead/social-justice-and-a-lost-chance-by-a-prime-minister/article69101922.ece', 'is_source_local': False, 'is_source_both': False, 'description': 'At the first official state dinner <strong>of</strong> his presidency, on November 24, 2009, Barack Obama, the first non-white President <strong>of</strong> the United States ...

# %%
web_result = response.json()['web']

# %%
from bs4 import BeautifulSoup

def extract_text_from_html(html_content):
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Get the text from the parsed HTML
    plain_text = soup.get_text()

    # Strip leading/trailing whitespace and return the result
    return plain_text.strip()

# %%
search_results = ""
n=0
for i in web_result['results']:
  if n == 5:
    break
  description = extract_text_from_html(i['description'])
  search_results+=description
  search_results+=f"\nSource link: {i['url']}\n----------\n"
  n+=1

  # search_results+=f"source url: "
  # print(i['title'])
  # print(i['url'])
  # print(description)
  # print("---------")
  # n+=1

# %%
print(search_results)
# Out:
# The prime minister of India (ISO: Bhārata kē Pradhānamaṁtrī) is the head of Union Council of Ministersof the Republic of India. Executive authority is vested in the prime minister and his chosen Council of Ministers, despite the president of India being the nominal head of the executive.
# Source link: https://en.wikipedia.org/wiki/Prime_Minister_of_India
# ----------
# Beti Bachao Beti Padhao (BBBP) was launched by the Prime Minister on 22nd January, 2015 at Panipat, Haryana. BBBP addresses the declining Child Sex Ratio (CSR) and related issues of women empowerment over a life-cycle continuum. It is a tri-ministerial effort of Ministries of Women and Child Development, Health & Family ... View More · Dynamic, dedicated and determined, Narendra Modi arrives as a ray of hope in the lives of a billion Indians...
# Source link: https://www.pmindia.gov.in/en/
# ----------
# The prime minister of India is the chief executive of the Government of India and chair of the Union Council of Ministers. Although the president of India is the constitutional, nominal, and ceremonial head of state, in practice and ordinarily, the executive authority is vested in the prime ...
# Source link: https://en.wikipedia.org/wiki/List_of_prime_ministers_of_India
# ----------
# Keynote Address: H.E. Prime Minister Narendra Modi, Prime Minister, India
# Source link: https://www.grandchallenges.org/video/keynote-address-prime-minister-narendra-modi-prime-minister-india
# ----------
